# %%
#開始進入聽不懂狀態
class My:
    x=5
m1=My()
print(m1.x)
m2=My()
print(m2.x)
m1.x=6
print(m2.x)
My.x=8
# Out:
# 5
# 5
# 5

# %%
#我解不出來
class Person:
  def _init_(self, name, age):
    self.name = name
    self.age = age

p1=Person('wang', 20)
print(p1.name, p1.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-391b7f1231df> in <module>()
#       4     self.age = age
#       5
# ----> 6 p1=Person('wang', 20)
#       7 print(p1.name, p1.age)
#
# TypeError: object() takes no parameters

# %%
#網路範本
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
class Myclass:
  x=5
p1 = Myclass()
print(p1.x)
# Out:
# 5
