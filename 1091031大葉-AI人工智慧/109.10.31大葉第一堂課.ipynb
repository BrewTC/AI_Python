# %%
print("109.10.31我來大葉上課")
print('深度學習感覺很難阿....\n 不過感覺很有趣')
# Out:
# 109.10.31我來大葉上課
# 深度學習感覺很難阿....
#  不過感覺很有趣

# %%
#變量
x = 5
y = '4321'
print(x,y)
# Out:
# 5 4321

# %%
a = 2
b = 3.14
print(a,b)
# Out:
# 2 3.14

# %%
a,b,c = 2,3,"阿不就好棒棒"
print("可以唷",a,b,c)
# Out:
# 可以唷 2 3 阿不就好棒棒

# %%
x="Hello"
def myfunc():
  global q
  print(q)
myfunc()
# Out:
# Hello

# %%
#數據類型
#list

# %%
x=3.4j
print(type(x))
# Out:
# <class 'complex'>

# %%
x=['a','b','c'] #list
print(type(x))
# Out:
# <class 'list'>

# %%
x=('a','b','c')
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={'a','b','c'} #set

# %%
a=range(6)
print(a)
b=list(range(6))
print(b)
c=bool(0)
print(c)
# Out:
# range(0, 6)
# [0, 1, 2, 3, 4, 5]
# False

# %%
import random  #亂數,後面會用到
print(random.randrange(0,100))
print(random.random())
# Out:
# 53
# 0.8584531630936382

# %%
#字符串
a="""prmrmv
ofmo3[f
[ofk[3o
"""
print(a[0:8])
print(a[-3])
# Out:
# prmrmv
# o
# 3

# %%
#format是啥?
age=33
a="hello {}"
print(a.format(age))
# Out:
# hello 33

# %%
a="你好我就\"爛\""
print(a)
# Out:
# 你好我就"爛"

# %%
a=3
b=2
if a>b:
  print('a>b')
else:
  print('a<b')
# Out:
# a>b

# %%
#運算子
x=100
y=10
print(x**y)
print(x//y)
# Out:
# 100000000000000000000
# 10

# %%
#list 字串有順序
a=['1','3','5','7']
print(a[1],a[3])
b=('1','3','5','7') #tuble,無法單獨列出順序,不能更改
print(b)
b[2]=6
# Out:
# 3 7
# ('1', '3', '5', '7')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-35c977e5d911> in <module>()
#       4 b=('1','3','5','7') #tuble,無法單獨列出順序
#       5 print(b)
# ----> 6 b[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
a=[0,1,2,3,4,5] #list
a.insert(2, 'hello') #插入一組
print(a)
# Out:
# [0, 1, 'hello', 2, 3, 4, 5]

# %%
a=[0,1,2,3,4,5]
del a[2]
print(a)
a.clear()
print(a)
# Out:
# [0, 1, 3, 4, 5]
# []

# %%
a=[1,'2',3]
b=[4,5,6]
c=a+b
print(c)
# Out:
# [1, '2', 3, 4, 5, 6]

# %%
#tuple 意思是?! 元組?
a=(1,2,3,4,4)
print(a.count(4))
b=('hello',)
print(type(b))
# Out:
# 2
# <class 'tuple'>

# %%
#集合
a={1,2,3,4,5}
a.add('7')
print(a)
b=a.pop()
print(b)
# Out:
# {1, 2, 3, 4, 5, '7'}
# 1

# %%
#字典
dict1={
  "a":1,
  "b":2,
  "c":3,
  "d":4,
}
print(dict1)
print(type(dict1))
dict1[2]='hey'
print(dict1)

for x in dict1:
  print(x)  #key
for x in dict1.values():
  print(x)  #
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# <class 'dict'>
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 2: 'hey'}
# a
# b
# c
# d
# 2
# 1
# 2
# 3
# 4
# hey

# %%
dict1={
  "a":1,
  "b":2,
  "c":3,
  "d":4,
}
dict1.popitem() #popitem()刪除最後一項
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict1={
  "a":1,
  "b":2,
  "c":3,
  "d":4,
}
del dict1["d"]  #刪除指定建名的項目
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
a=3
b=2
if a>b:
  print('>')
elif a<b:
  print('<')
else a=b:
  print('=')
# Out:
#   File "<ipython-input-88-b1aa9da55620>", line 7
#     else a =b:
#          ^
# SyntaxError: invalid syntax

# %%
i=1
while i<6:
  i+=1 
  if i==3: continue
  print(i) #12345
  if i==3: break
  print(i)
# Out:
# 2
# 2
# 4
# 4
# 5
# 5
# 6
# 6

# %%
i=1
while i<6:
  print(i)
  i+=1
else:  ??
  print(">=6")
# Out:
# 1
# 2
# 3
# 4
# 5
# >=6

# %%
for x in range(2,30,3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
sum=0
for x in range(100,1,-1):
  sum+=x
print(sum)
# Out:
# 5049

# %%
for x in range(6):
  print(x)
  pass #為空白
else:
  print(">=6")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# >=6

# %%
#類別
