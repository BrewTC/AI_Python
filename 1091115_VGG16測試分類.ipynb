# %%
import tensorflow as tf
from  tensorflow.keras.layers import Dense,Conv2D, MaxPooling2D, Flatten
shape1 = (224, 224, 3)

model=tf.keras.Sequential([
  Conv2D(64,(3,3), input_shape=shape1,padding='same',activation='relu'),                        
  Conv2D(64,(3,3), padding='same', activation='relu' ),
  MaxPooling2D( pool_size=(2,2), strides=(2,2) ),
  Conv2D(128,(3,3), padding='same',activation='relu'),                        
  Conv2D(128,(3,3), padding='same', activation='relu' ),
  MaxPooling2D( pool_size=(2,2), strides=(2,2) ), 
  Conv2D(256,(3,3), padding='same',activation='relu'),                        
  Conv2D(256,(3,3), padding='same', activation='relu' ),
  Conv2D(256,(3,3), padding='same', activation='relu' ),
  MaxPooling2D( pool_size=(2,2), strides=(2,2) ), 
  Conv2D(512,(3,3), padding='same',activation='relu'),                        
  Conv2D(512,(3,3), padding='same', activation='relu' ),
  Conv2D(512,(3,3), padding='same', activation='relu' ),
  MaxPooling2D( pool_size=(2,2), strides=(2,2) ),   
  Conv2D(512,(3,3), padding='same',activation='relu'),                        
  Conv2D(512,(3,3), padding='same', activation='relu' ),
  Conv2D(512,(3,3), padding='same', activation='relu' ),
  MaxPooling2D( pool_size=(2,2), strides=(2,2) ), 
  Flatten(),
  Dense(4096,activation='relu' ),
  Dense(4096,activation='relu' ),
  Dense(1000,activation='softmax' )
]) #Total params: 138,357,544 1憶4千萬左右個weight. 
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5bb04a8e-bae6-4d12-b0e3-268a8c5e5ae3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bb04a8e-bae6-4d12-b0e3-268a8c5e5ae3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.zip to images.zip
# {'images.zip': b'PK\x03\x04\x14\x00\x00\x00\x00\x00\x02joQ\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x07\x00\x00\x00images/PK\x03\x04\x14\x00\x00\x00\x08\x00\xe2ioQ\xdbh\xd6\x7f\xb4\x86\x02\x00\x19\x87\x02\x00\x1d\x00\x00\x00images/20001976iZDCd0ez35.jpg\x9c\x9agT\x93M\x16\xc7\x9f\x90\xd0{\xe8\xd5@B\r\xbd(\xdd\x00\x02\x01\xa4\xf7*\xbd\xd7 ]\xd8\x00\x82\x94\x00\xa1+"E\xbat\x0c]\xa4w\x01)\xd2A\x9a\xd2\x84\x17\x10\x11\x15}\xd7\xdd\xb3\xe5\xcb~\xd8\xdd\xff\xcc\xb7;3g~g\xee\x99\xb93w\xfe\\\xfas\x13\xa0\xd3\xd1\xd4\xd6\x04@ \x10\xe0\xf0\xbb\x00\x7f\xfe\x02\x14\xd5\x8d5TM\r\x8c\x15`\xee.\xa2^\x01\xae\xee\xb0\x10I1\t\x98`p\x90\xa7\x9f;L[G\x0b\xa6c\xa8\xa1\x05\x0b\x91\x93\x10\x12\x81\x05\x06;\xfax\xde\x0f\x87)\xc3\xe4%(\xfe\\\x05\xd4\x010\x11\xd1\xdf\xeaoA~Wb2bb\x08\x84\x98\x82\x94\x94\x84\x8c\x8a\x82\x8a\x8a\x92\x82\x92\x92\x9a\x06JGMCOCII\xc7LG\xcf\xc0\xc8\xc4\xc4DE\xcb\xc2\xca\xcc\xc8\nedb\xfc\xdb  \xf0\xef>\x10brbbrFjJj\xc6\xffY\x7f\xf6\x02\xf4dDTD\xaf\xc0 ^\x80\x88\x1e\x04\xa6\x07\xfd9\x08\xdc\x00\x00\x101\xe8\xef\x02\xfe!\x10\xd1\xef9\x92\x90\x92\x91SP\xfen\xd0B\x07\x10\x81\xc0`"\x08\xf8o\xb3\xfem\x8d\xfam\x07 \xf4\xc4P\x1eIU\x12\x06#GR\xde@F\xa9\x98\x8c\x122\xb8ZS\x1f\x93\xf1\xcc)B\xda\t\x13KN\xc1\xcc\xc2\xca\xc6\xce\xc7/ ($,#{\xf3\x96\x9c\xbc\x82\xfa\x1d\rM-\xb4\xb6\x8e\x89\xa9\x99\xb9\x85\xa5\x95\xb5\xb3\x8b\xab\x9b\xbb\x87\xa7W\xd0\xfd\xe0\x90\xd0\xb0\xf0\x88\xb8\x87\xf1\t\x8f\x12\x93\x923\xb3\xb2sr\xf3\x1e?\xc9\x7f^ZV^QYU\xfd\xa2\xf9%\xa1\xa5\xb5\xad\xbd\xa3\xb3\x7f`phxdtl|vn\xfe\xdd\xc2\xe2\xd2\xf2\xca\xd6\xf6\xce\xee\x87\x8f{\xfb\x07\x87g\xe7\x9f/\xbe\\~\xbd\xfa\xf6\xfdo\\ \x00\x0c\xfa\xa7\xfe#\x17\xfdo."\x08\x04\x0c!\xfd\xcd\xf5\xdb\x18\xfa\xb7\x06\xf4\x10b\x1eI\x12\xa8\xaa\x11\xa9c \x03\xafT\x0c\x19\xa3ZFIS\x1f9\\\xda\xf8\x94\xc9\t3C\xc1\x8c\x90\xd9\xe2;\xfb\x1b\xda\xdf\xc9\xfe;\xb0\xd8\xff\x8b\xec_`\xff\xe6Z\x01\xa8\xc0\xa0\xdf\x8b\x07\xa6\x07n\x03?\x99`1C\xfc\xd2\x8bu\xfa\xe1\x9f\x04\x1b\x8a?*M\xd8>\xe4W0f\xe4\x8b\xd9.\x87\x13a\xa5\x04\xdb\xad\x07\xd0\x93\x80sr\x00\x9bL\xbc~Xy\x00=\x9d\xd0m\x9d\xbbne+\x1a\xfc\xfdBk"K\xd9\xc5ny\x8e\xc5T\xc6\xed\xf4\xe1\xea2\xe1\xf2\x1f\xcb{\xcb+\xdf\xf4\xd6\xbf05iDWW\x93\xfd\xa1%\x81l\xe6O\xe1\x7f\xec\x8c|\xeb~`~\x93\xdd?W{Zf>1\xf3%\xd2G\xe69\xefF\x8e\xbb{\x9d\xd8\x8cA\x81\xb9\xab\tK\t\xe3\x9aY)+8\x06m\xb2\x90\x9f\xd3W\xc3\x84\xc79\xc4z\xa2\xc7\xbei\n;\xd21\xa6r\x1b0\x9e<\xd4hM%|\nJ6Lx\xdc\xc6s}\x10\x94\xfc\x94#\x1c\xfc\xb9\xec\xfc\xf3\xa4\x8a\x0b\xbaW\xb2\xe8@\xf7\x0b\xe9y\xf5;\xa2\x8b\xf2\xe5\xc2w\x9c\xa3!P\x99a\xcfUO\xb5\xed\xdc\xe7\xdbo\xe3\xe7\xd3\x84\xa1\x8fdC\xdd<\x95\x8a\x15\xfe\x04\x14\xbc\xcc\xa9\x99\x87$*eyG\xda\xddj\xc3\x1d.J\'\x88\x1eI k\x1d(\xbc1\x12\xca^S\xb3\x9a\x92w\xcfG+\xca\xa3z\x1f\x12y\x08k\x18\xa8r\xbc\xa8G\xbe.\x8f\x10\xbe\'\x182\xa9\x0c_\xb9\xcd.\xee\xb0\xd6\xa0\xa1o\x98\xa1S\x1d3)\xe6(3:\xab\xc49W\x94\x91>\\\xd4\x1a\x8b\x9d_\x83z\xdca#\x89}rd`\x08*_\xd5\xf9@\x7f\xbc>$o\xe2\xb8S\xa7\x92\x8cgW\x1d\x02\xe9\x0b}\xbbdt_2\x86j+\xa6\xae\xa25\x85\xf5*\xb0\x92\x1a\xc3\xd2\x8e\xe5\x14\x81f\xc1z^\xab\xda\xf4\xe1\x1fz\xc2\xb6@`\x98\xbb<\xe2\x12\x10\x92W\xa2h\x11\x1d\xd7\xe0\xfe<\n\xcb\x01Cz\xd8\x80\xa01\xde\x921QK\xce\xa2A\x03\xce\xca\x98\x8b \xb9G\xc7\xb70H\xd6R\xb9^\x80\xa1\xa3Y\x8b\xd3\x19\\\xdd[/\xbe\xf5~h]k(\xdf\xbcE\x8c\x97%\x97\x02A\xb6\xd9\xe8\x04r\x03@\x99\xa8\x1d\xaet\xe5\xa3\xb8\xab\xb6\xedu\xc5A\xeb\xe3\xa1\x1f\xeb\xeb\xaa\x9e\xce\xf4m\xb9\xac\x9b\xeb-}\xac\x1c}\xc2h\'r\x90>\xf0\x87}\xd4\xe6=\xae\xe50\xcc\xf7\x0b\xed\xda\xe9\x9f\xa9\xf2\x19\x0e\x8f\x85D\x9e\xf4\xba\xbb\xa2T\x0c\xb5!4:\xb1aL[\xa6C\xb26Z%\x04\xe7\xf2\xe5\x83\x88\x91!A\xb1/\xe1\x1b\x91\x83\xe1\xee\x86{\x93\xf8\xe7\xab\x99d\xa8\x8c\x8c.\xaaP\x17\x1a\xf4\xb4\xcf\xe2\xe3\xb0\xae\xa1G\xfd_\xbd\xab\r\x14\xfb\x98g\xa0\xdf\x02>2?\xa0c\x15\xd8\x10\xd1bu\x8cE++\x04l(\x9e\xa5\x12:\xd7\xaa\xa0K\x06\x1e\xd3\x1fmV\xd4\x067\xf1 \x1a\xed1E}}2\x8es)/\x7f&\x0f\x16\x85\xf7\x8f\x08\x83\xcd\x84\xa2\xbbt\xb6J5\xfe\xa1\xfd\xb5Qw\xd2y\x00\xa0\x86\xe0@\x14\xae|4\xd8\xa0\xff\x8eq\x0f\xb9vd\xfb\xaa\x9a\xaf\xdazz[j\xa0 ...

# %%
# !unzip images.zip
# Out:
# Archive:  images.zip
#    creating: images/
#   inflating: images/20001976iZDCd0ez35.jpg
#   inflating: images/20001976oRZNQugNBD.jpg
#   inflating: images/bear and dog.jpg
#   inflating: images/bird01.jpg
#   inflating: images/elephant2.jpg
#   inflating: images/input.jpg
#   inflating: images/input1.jpg

# %%
from tensorflow.keras.preprocessing import image
img_path = './images/input.jpg'
img=image.load_img(img_path, target_size=(224,224))
x=image.img_to_array(img) #(224, 224, 3)
x1=np.expand_dims(x, axis=0) #(1,224,224,3)
x2 = preprocess_input(x1)

# %%
import numpy as np
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.applications.vgg16 import VGG16 

model = VGG16(weights='imagenet', include_top=True)

# %%
# 預測，取得features，維度為 (1,7,7,512)
features = model.predict(x2)
# 取得前三個最可能的類別及機率
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# Predicted: [('n04357314', 'sunscreen', 0.3246376), ('n04493381', 'tub', 0.18397419), ('n02808440', 'bathtub', 0.13666768)]

# %%
features=model.predict(x)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_1:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 1, 1, 1, 224, 224, 3).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-eabd648f6c7a> in <module>()
# ----> 1 features=model.predict(x)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     695     self._concrete_stateful_fn = (
#     696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 697             *args, **kwds))
#     698
#     699     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1462 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1452 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1445 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1418 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py:985 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py:386 call
#         inputs, training=training, mask=mask)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py:508 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py:976 __call__
#         self.name)
#     /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/input_spec.py:180 assert_input_compatibility
#         str(x.shape.as_list()))
#
#     ValueError: Input 0 of layer block1_pool is incompatible with the layer: expected ndim=4, found ndim=7. Full shape received: [None, 1, 1, 1, 224, 224, 64]
