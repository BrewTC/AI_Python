# %%
# -*- coding: utf-8 -*-

import math
import matplotlib.pyplot as plt
import numpy as np

X = [] #空集合
dx = -20
while dx<=20:
  x.append(dx)
  dx += 0.1

def sigmoid(x):
  y = 1.0/(1+math.exp(-x))
  return y
px = [xv for xv in x]
py = [sigmoid(xv) for xv in x]

plt.plot(px,py)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))p
lt.show()

# %%
# -*- coding: utf-8 -*-
import math
import matplotlib.pyplot as plt
import numpy as np

x = []
dx = -20
while dx <= 20:
    x.append(dx)
    dx += 0.1


def sigmoid(x):
    return 1/(1+math.exp(-x))


px = [xv for xv in x]
py = [sigmoid(xv) for xv in x]


plt.plot(px, py)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()

# %%
# -*- coding: utf-8 -*-
import math
import matplotlib.pyplot as plt
import numpy as np

value=-10
x=[value +n*0.01 for n in range(2001)]
y=[math.tanh(v) for v in x]
print(len(x))

x = []
dx = -20
while dx <= 20:
    x.append(dx)
    dx += 0.1


def sigmoid(x):
    return 1/(1+math.exp(-x))


px = [xv for xv in x]
py = [sigmoid(xv) for xv in x]


plt.plot(px, py)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()
# Out:
# 2001

# %%
# -*- coding: utf-8 -*-
import math
import matplotlib.pyplot as plt
import numpy as np

def ReLU(x):
  if x < 0: return 0
  else: return x
value=-10
x=[value +n*0.01 for n in range(2001)]
y=[math.tanh(v) for v in x]
print(len(x))

x = []
dx = -20
while dx <= 20:
    x.append(dx)
    dx += 0.1


def sigmoid(x):
    return 1/(1+math.exp(-x))


px = [xv for xv in x]
py = [sigmoid(xv) for xv in x]


plt.plot(px, py)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()
# Out:
# 2001

# %%
import tensorflow as tf
x=tf.linspace(-6,6,10)
print(x)
y=tf.nn.sigmoid(x)
print(y)
y=tf.nn.softmax(x)
plt.plot(x,y,'o')
# Out:
# tf.Tensor(
# [-6.         -4.66666667 -3.33333333 -2.         -0.66666667  0.66666667
#   2.          3.33333333  4.66666667  6.        ], shape=(10,), dtype=float64)
# tf.Tensor(
# [0.00247262 0.00931596 0.0344452  0.11920292 0.33924363 0.66075637
#  0.88079708 0.9655548  0.99068404 0.99752738], shape=(10,), dtype=float64)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
o=tf.random.normal([2,10])
o.shape
y_onehot=tf.constant([1,3])
y_onehot=tf.one_hot(y_onehot, depth=10) #數字轉換成向量
loss=keras.losses.MSE(y_onehot, o)
loss
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.8255526, 0.5960649], dtype=float32)>
